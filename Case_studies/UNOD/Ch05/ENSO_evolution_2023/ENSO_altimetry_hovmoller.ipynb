# %% [markdown]
# <img src='https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/tools/frameworks/-/raw/main/img/UN_decade_banner.png' align='right' width='100%'/>

# %% [markdown]
# <a href="../../../../Index.ipynb"><< Index</a>

# %% [markdown]
# <font color="#138D75">**Copernicus Marine Training Service**</font> <br>
# **Copyright:** 2024 European Union <br>
# **License:** MIT <br>
# **Authors:** Vinca Rosmorduc (CLS), Ben Loveday (EUMETSAT/Innoflair UG), Hayley Evers-King (EUMETSAT)

# %% [markdown]
# <html>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies"><img src="https://img.shields.io/badge/open-EUMETLAB-E67E22.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://user.eumetsat.int/data/themes/marine"><img src="https://img.shields.io/badge/open-USER PORTAL-154360.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://mybinder.org/v2/git/https%3A%2F%2Fgitlab.eumetsat.int%2Feumetlab%2Foceans%2Focean-training%2Fapplications%2Focean-case-studies/HEAD?labpath=Case_studies%2FUNOD%2FCh05%2FENSO_evolution_2023%2FENSO_altimetry_hovmoller.ipynb"><img src="https://mybinder.org/badge_logo.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://jupyterhub.prod.wekeo2.eu/hub/user-redirect/lab/tree/public/wekeo4oceans/ocean-case-studies/Case_studies/UNOD/Ch05/ENSO_evolution_2023/ENSO_altimetry_hovmoller.ipynb"><img src="https://img.shields.io/badge/launch-WEKEO-1a4696.svg"></a></div>
#    <div style="float:left"><p>&emsp;</p></div>
#    <div style="float:left"><a href="https://code.insula.destine.eu/hub/"><img src="https://img.shields.io/badge/launch-DestinE-f43fd3.svg"></a></div></div>
# </html>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <h3>Ocean case studies</h3></div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <b>PREREQUISITES </b>
#
# This notebook has the following prerequisites:
# - A **<a href="https://data.marine.copernicus.eu/register" target="_blank">Copernicus Marine Service account</a>** to access the required data
#
# </div>
# <hr>

# %% [markdown]
# # Observing marine ENSO progression throughout 2023
# <font color="#138D75">**UN Ocean Decade Challenge 5: Unlock ocean-based solutions to climate change**</font>
#
# ### Data used
#
# | Dataset | Copernicus Marine<br>Data Store product ID | Copernicus Marine<br>product description | WEkEO<br>dataset ID | WEkEO<br>dataset description |
# |:--------------------:|:-----------------------:|:-------------:|:-----------------:|:-----------------:|
# | Global Ocean Gridded L4 Sea Surface Heights <br> & Derived Variables (NRT)| SEALEVEL_GLO_PHY_L4_NRT_008_046 | <a href="https://data.marine.copernicus.eu/product/SEALEVEL_GLO_PHY_L4_NRT_008_046/description" target="_blank">Description</a> | EO:MO:DAT:SEALEVEL_GLO_PHY_L4_NRT_008_046 | <a href="https://www.wekeo.eu/data?view=dataset&dataset=EO%3AMO%3ADAT%3ASEALEVEL_GLO_PHY_L4_NRT_008_046" target="_blank">Description</a> |
#
# ### Learning outcomes
#
# At the end of this notebook you will know how to;
# * download sea level anomaly (SLA) altimetry products from the Copernicus Marine Service
# * calculate mean weekly SLA values over a defined region
# * create and interpret a longitude vs time Hovmoller plot of the data over the tropical Pacific
#
# ### Outline
#
# El Niño-Southern Oscillation (ENSO) is a natural coupled ocean-atmospheric pattern occurring in the tropical Pacific, but with global impacts. Its cycle ranges between 2 to 7 years causing a variation in temperature of the upper ocean. While El Niño describes the unusual warming of surface waters, La Niña represents the opposite effect and it is often reported as the “cool phase”. The phenomenon was first recorded through observations made by Peruvian fisherman in December during the 18th century. Because of its correspondence with the Christian holy day Christmas, the event was named after the Christ child, literally “the little boy” or “El Niño” in Spanish. Early in the 19th century, the ocean signal was found to correspond with atmospheric events on the other side of the tropical Pacific Ocean - know as the “Southern Oscillation”. ENSO has an extensive influence on regional temperature, precipitation and weather patterns, and effects ocean productivity and fisheries by changing the dynamics of upwelling systems. Consequently, ENSO has attracted significant interest from the scientific community and government agencies, who seek to understand both the drivers and ramifications of its more extreme phases. Strong El Niño events, which are associated with vast amount of heat rising from the Pacific waters and often causing the hottest years in records, are increasing in frequency due to climate change [1], exacerbating our need to monitor and respond to them.
#
# With the advent of satellites technologies, the scientific knowledge regarding the wide-range effects of ENSO on the planet has improved significantly. Earth observation gives us the tools to track the development and effects of the phases of ENSO globally, giving us an up-to-date view across the ocean, land and in the atmosphere. Ocean-observing satellites such as Sentinel-3 and Sentinel-6 give us detailed insights into changes in the sea-surface height (via the SRAL and Poseidon-4 altimeters), sea surface temperature (SLSTR) and ocean colour (OLCI). These observations are essential inputs to downstream products, which integrate information from multiple sensors, and give us the best view of the evolving ENSO situation. These downstream products include those offered by the Copernicus Marine Service, which we use here.
#
# In this Jupyter Notebook we will work through an example of how you can access Level-4 sea level anomaly data from the Copernicus Marine Service. We will show how to manipulate the data to give us weekly spatial anomalies over our area of interest. Finally, we will show how to make and interpret a "Hovmoller" plot of time vs longitude to track these sea level anomalies as the move across the tropical Pacific Ocean. This Jupyter Notebook builds on the <a href="ADD LINK!" target="_blank">Observing marine ENSO progression throughout 2023</a> case study, and will replicate figure 1 from it.
#
# As part of the <a href="https://www.oceandecade.org/" target="_blank"> United Nations Ocean Decade</a>, ten specific <a href="https://oceandecade.org/challenges/
# " target="_blank">challenges</a> are being addressed. This work, and the data underlying it, support Challenge 5 - Unlock ocean-based solutions to climate change. Long-term satellite records, such as those from the altimetry missions, allows us to monitoring the evolution of interannual to decadal climate modes such as ENSO and provide us with essential information on the how these patterns are evolving under climate change and insight into the global consequences of the extremes that they bring.
#
# ### References
#
# [1] Cai, W., Borlace, S., Lengaigne, M., Van Rensch, P., Collins, M., Vecchi, G., ... & Jin, F. F. (2014). Increasing frequency of extreme El Niño events due to greenhouse warming. Nature climate change, 4(2), 111-116.
#
# [2] Luo, X., Keenan, T. F., Fisher, J. B., Jiménez-Munoz, J. C., Chen, J. M., Jiang, C., ... & Tadić, J. M. (2018). The impact of the 2015/2016 El Niño on global photosynthesis using satellite remote sensing. Philosophical Transactions of the Royal Society B: Biological Sciences, 373(1760), 20170409.
#
# [3] Kogan, F. N. (2000). Satellite-observed sensitivity of world land ecosystems to El Nino/La Nina. Remote Sensing of Environment, 74(3), 445-462.
#
# [4] Asner, G. P., Townsend, A. R., & Braswell, B. H. (2000). Satellite observation of El Nino effects on Amazon forest phenology and productivity. Geophysical research letters, 27(7), 981-984.
#
# [5] Li, Y., Lu, H., Entekhabi, D., Gianotti, D. J. S., Yang, K., Luo, C., ... & Jiang, R. (2022). Satellite-based assessment of meteorological and agricultural drought in Mainland Southeast Asia. IEEE Journal of Selected Topics in Applied Earth Observations and Remote Sensing, 15, 6180-6189.
#
# <div class="alert alert-info" role="alert">
#
# ## <a id='TOCTOP'></a>Contents
#
# </div>
#
#  1. [Step 1: Setting up our analysis](#section1)
#  1. [Step 2: Downloading level-4 altimetry data](#section2)
#  1. [Step 3: Preparing the data](#section3)
#  1. [Step 4: Making a Hovmoller plot](#section4)
#  1. [Step 5 (Optional): Challenge](#section5)
#
# <hr>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>1. Setting up our analysis
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# We begin by importing all of the libraries that we need to run this notebook. If you have built your python using the environment file provided in this repository, then you should have everything you need. For more information on building environment, please see the repository **<a href="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies/-/blob/main/README.md?ref_type=heads" target="_blank">README</a>**.

# %%
import copernicusmarine         # this library supports access to the Copernicus Marine Service catalogue via API
import numpy as np              # a library that lets us work with arrays; we import this with a new name "np"
import matplotlib.pyplot as plt # a library the provides plotting capability
from pathlib import Path        # a library to help us to construct system paths
import warnings                 # a library that helps us handle warnings

warnings.filterwarnings('ignore')
plt.rcParams.update({'font.size': 32})

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section2'></a>2. Downloading level-4 altimetry data
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# We are going to work with the level-4 sea level anomaly altimetry product from the Copernicus Marine Service Data Store. Level-4 altimetry products contain data from multiple altimeters, including Sentinel-3A and 3B SRAL and Sentinel-6. However, while level-2 products contain along-track data from individual instruments, and level-3 products contain along-track data from multiple instruments, the level-4 merges the level-3 product using optimally interpolation. This results in a fully gridded field. You can find more informaion on this process via the links under the Data Used section, above.

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# ### Accessing Copernicus Marine Service products
#
# To retrieve the data, we need will use the <a href="https://help.marine.copernicus.eu/en/articles/7949409-copernicus-marine-toolbox-introduction" target="_blank">Copernicus Marine API</a>. This allows us to remotely subset the data and read it directly into memory, for immediate use. If you are working with the recommended Anaconda Python distribution and used the environment file included in this repository (environment.yml) to build this python environment (as detailed in the README), you will already have installed this. If not, you can install the toolkit using;
#
# `conda install -c conda-forge copernicusmarine`
#
# To download data using the Copernicus Marine API, you need to provide credentials. To obtain these, you should register at the <a href="https://data.marine.copernicus.eu/register" target="_blank">Copernicus Marine Service</a> for an account and take note of you `username` and `password`. If you do not already have a local credentials file, you will be prompted to enter your credentials when you run the cell below. This will create the required local credentials file, so that you only need to run this once.
#
# *Note: For more information on authentication options please see this <a href="https://help.marine.copernicus.eu/en/articles/8185007-copernicus-marine-toolbox-credentials-configuration" target="_blank">web article</a>.*
#
# </div>

# %%
# Default location expected by the copernicusmarine package
copernicus_marine_credentials_file = Path(Path.home() / '.copernicusmarine' / '.copernicusmarine-credentials')

# Create it only if it does not already exists
if not copernicus_marine_credentials_file.is_file():
    copernicusmarine.login()

# %% [markdown]
# Now that we have anuthenticated the API, we can retrieve our data. The cell below will do that, but note that we had to define some key pieces of information first;
# * we need to specify the limits of our region interest (minimum_logitude etc.)
# * we need to specify our time bounds in the correct format (start_datetime / end_datetime)
# * and we need to specify the dataset_id and variables we want.
#
# The **dataset_id** is a little complex to find as it is not the same as the product ID we reference above. Many products contain multiple datasets, and we need to reference the correct one. You can find the datasets under each product by using the <a href="https://data.marine.copernicus.eu/product/SEALEVEL_GLO_PHY_L4_NRT_008_046/download" target="_blank">"download" service</a> link. This link will also tell you which **variables** are available, and what they are called. The variables should be stored as strings in a comma separated list, e.g. ["var1", "var2" "var3"], as below.
#
# Once we have populate all this information, we can run the cell below to prepare and retrieve our data.

# %%
ds = copernicusmarine.open_dataset(
   dataset_id = "cmems_obs-sl_glo_phy-ssh_nrt_allsat-l4-duacs-0.25deg_P1D",
   minimum_longitude = 120,
   maximum_longitude = 280,
   minimum_latitude = -2,
   maximum_latitude = 2,
   start_datetime = "2022-01-01 00:00:00",    
   end_datetime = "2024-02-29 23:59:59", 
   variables = ['sla'], 
)
# Out:
# INFO - 2025-06-10T13:28:40Z - Dataset version was not specified, the latest one was selected: "202311"
# INFO - 2025-06-10T13:28:40Z - Dataset part was not specified, the first one was selected: "default"
# INFO - 2025-06-10T13:28:41Z - Service was not specified, the default one was selected: "arco-time-series"

# %% [markdown]
# Now we should have all of our data ready to use and stored in the "ds" `xarray.Dataset` object. Lets see what we have.....

# %%
ds
# Out:
# <xarray.Dataset> Size: 65MB
# Dimensions:    (time: 790, latitude: 16, longitude: 640)
# Coordinates:
#   * latitude   (latitude) float32 64B -1.875 -1.625 -1.375 ... 1.375 1.625 1.875
#   * time       (time) datetime64[ns] 6kB 2022-01-01 2022-01-02 ... 2024-02-29
#   * longitude  (longitude) float32 3kB 120.1 120.4 120.6 ... 279.4 279.6 279.9
# Data variables:
#     sla        (time, latitude, longitude) float64 65MB ...
# Attributes: (12/44)
#     Conventions:                     CF-1.6
#     Metadata_Conventions:            Unidata Dataset Discovery v1.0
#     cdm_data_type:                   Grid
#     comment:                         Sea Surface Height measured by Altimetry...
#     contact:                         servicedesk.cmems@mercator-ocean.eu
#     creator_email:                   servicedesk.cmems@mercator-ocean.eu
#     ...                              ...
#     summary:                         SSALTO/DUACS Near-Real-Time Level-4 sea ...
# ...

# %% [markdown]
# You should see that you have an `xarray.Dataset` with `Dimensions` of **time**, **latitude** and **longitude** also containing the **sla** `Data variable`. If not, something has gone wrong and you should contact us for support using the email address at the bottom of this notebook so that we can investigate for you!

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section3'></a>3. Preparing the data
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Now we have our data, our preparation steps are very simple (thanks to the magic of xarray!). First, we are going to average our dataset average all latitudes. This will give us the two dimensional record of longitude vs time that we need for our Hovmoller plot.

# %%
# average over the latitudes without NaNs
nclatmean = ds.mean(dim='latitude', skipna=True)

# %% [markdown]
# Now we are going to resample the time dimension so that we have weekly mean values. We do this to smooth our data a little as are not interested in the changes in our signal on very short timescales.

# %%
# resample weekly
nclatmean_weekly = nclatmean.resample(time='W', skipna=True).mean()

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section4'></a>4. Making a Hovmoller plot
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Now we are ready too plot our data. First, to set up our 2-dimensional axes, we will create the time2 and lon2 from our 1-dimensional longitude and time coordinates.

# %%
# create a longitude-time grid to plot.
time2, lon2 = np.meshgrid(nclatmean_weekly.longitude, nclatmean_weekly.time)

# %% [markdown]
# Next, we will define the limits our of colour bar, as below.

# %%
# Here, we define min / max of the color bar. We shift the colorbar middle 
# in order to balance colors in the plot since sla are referenced to a 20-year
# average, not the current 30+ years available
colormax = np.round(np.nanmax(nclatmean_weekly.sla), 2)
colormin = np.round(np.nanmin(nclatmean_weekly.sla), 2)

# %% [markdown]
# Now lets set up our figure and make our plot. We will also save it the figure.

# %%
# set up our figure
fig = plt.figure(figsize=(35,25))

# set up our axes
ax = fig.add_subplot()
ax.invert_yaxis()

# plot out main panel of data; the Hovmoller plot
mm = ax.pcolormesh(time2, lon2, nclatmean_weekly.sla, vmin=colormin, vmax=colormax, cmap='RdYlBu_r')

# label and tidy up our plot
ax.grid(color='gray', linestyle='--', linewidth=2)
ax.set_xlabel("Longitude")

# plot our colorbar
cbar = fig.colorbar(mm, orientation='horizontal', pad=0.08, shrink=0.66, aspect=36)
cbar.set_label('Sea Level Anomaly [m]', fontsize=36)

# save our plot
plt.savefig('hovmoller_ENSO_2022-2024.png', dpi=150, bbox_inches='tight', pad_inches=0.01)

# %% [markdown]
# We have now created our Hovmoller plot! Hovmoller plots are a common way to visualise oceanographic data and effectively shows the movement of a signal, such as a wave, on a single spatial axis (in our case longitude) over time.
#
# During El Niño events, a weakening of the prevailing east-west trade winds gives rise to a characteristic increase in sea level (in red around January 2023 on the left hand side of our plot, around 120°E), which travels across the tropical Pacific basin west to east from Indonesian waters to the coast of Central and South America by around July 2023. The impact of the La Niña from the previous year (2022), can also be seen in the lower sea level on the eastern coasts of the basin (the dark blue are in January 2022 around 240°E-280°E).

# %% [markdown]
# <div class="alert alert-success" role="alert">
#
# ## <a id='section5'></a>5. Challenge
# [Back to top](#TOCTOP)
#
# </div>

# %% [markdown]
# Above we have made a Hovmoller plot showing the sea level anomaly signal for the 2023 El Nino event. However, you can adapt the above to look at the signals associated with other events. For example, try looking at some other strong El Nino and La Nina events, such as those described <a href="https://ggweather.com/enso/oni.htm" target="_blank">here<a/>.

# %% [markdown]
# <hr>
# <a href="../../../../Index.ipynb"><< Index</a>
# <hr>
# <a href="https://gitlab.eumetsat.int/eumetlab/oceans/ocean-training/applications/ocean-case-studies">View on GitLab</a> | <a href="https://training.eumetsat.int/">EUMETSAT Training</a> | <a href=mailto:ops@eumetsat.int>Contact helpdesk for support </a> | <a href=mailto:training@eumetsat.int>Contact our training team to collaborate on and reuse this material</a></span></p>
